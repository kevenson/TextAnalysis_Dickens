# %% [markdown]
# # Text Analysis using TextBlob

# %% [markdown]
# In this lesson, we'll expore text analysis using [TextBlob](http://textblob.readthedocs.io/en/dev/). TextBlob is a Python library for processing textual data, which provides a simple API (*application programming interface*) for diving into common natural language processing (NLP) tasks such as part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more.
#
# *Note: a "library" (or "module") is just programming-speak for an extension. It's something we can add to our Python installation in order to get special abilities.*
#
# The process to `import` a library into your Jupyter Notebook is very simple, but in order to do so, we must first install the library on the computer.

# %% [markdown]
# ##### Installing TextBlob on your computer
# To [install TextBlob](http://textblob.readthedocs.io/en/dev/install.html) on your computer, open the Anaconda3 folder in the Start menu (Start -> All Programs -> Anaconda3 (64-bit)), and select the Anaconda Prompt.
#
# In the window that opens, type `pip install textblob` and hit enter. You should see the installation process and the message "Successfully installed textblob-0.15.1" when the installation is complete.
#
# Now, we also need to install the NLTK corpora that we will use with TextBlob. To do this, in the Anaconda Prompt window, type: `python -m textblob.download_corpora` and hit enter.

# %% [markdown]
# ##### Importing TextBlob into your Notebook

# %% [markdown]
# Now that we've installed TextBlob on our computer, we can start using it in our Jupyter Notebook. To do this, we first need to `import` the library:

# %%
# run the code block below to import TextBlob 
from textblob import TextBlob

# Note: the two lines below download a tokenizer used by TextBlob 
# and are only necesary on PCs
#import nltk
#nltk.download('punkt')
#nltk.download('corpora/brown')

# %% [markdown]
# Note that it might take a few moments for TextBlob to be imported.
#
# Now, let's test TextBlob to make sure it's working properly:

# %%
blob = TextBlob("It was the best of times, it was the worst of times...")
print(blob)
# Out:
# It was the best of times, it was the worst of times...

# %% [markdown]
# This small piece of code takes a string ("It was the..."), and uses the TextBlob library we imported to create a special TextBlob object we have named "blob".
#
# Now that we know TextBlob is working, let's try using one of the built-in functions:

# %%
# what do you think this will do?

print(blob.translate(to="es"))
# Out:
# Fue el mejor de los tiempos, fue el peor de los tiempos ...

# %% [markdown]
# That last line of code takes our `blob` object and translates it, using the [Google Translate API](https://cloud.google.com/translate/). The free version of Google Translate is included in TextBlob.

# %% [markdown]
# ### Quiz 1: In the space below write a function that takes a string as an argument and translates it into another language.
#
# Hint: you may want to refer to the documentation [here](http://textblob.readthedocs.io/en/dev/quickstart.html#translation-and-language-detection).

# %%
# add your code here

def translate_string(string, language):
    "Read the contents of STRING and return as a translated TextBlob object."
    contents = string
    blob = TextBlob(contents)
    translated_copy = blob.translate(to=language)
    return translated_copy

text = translate_string("It was the best of times", "ar")
print(text)
# Out:
# كانت من افضل الاوقات

# %% [markdown]
# ------

# %% [markdown]
# Before we dive in deeper, let's write a quick function that will make it easy to retrieve TextBlob objects based on a selected file. This will make it easier to use TextBlob to analyze the novels we have saved in our `data/` directory.
#
# Remember how to read files? Each time we had to open a file, read the contents and then close the file. Since this is a series of steps we will often need to do, we can write a single function that does all that for us. We write a small utility function read_file(filename) that reads the specified file and simply returns all contents as a TextBlob object that we can work with.

# %%
def read_file(filename):
    "Read the contents of FILENAME and return as a TextBlob object."
    infile = open(filename, encoding="utf8")
    contents = infile.read()
    blob = TextBlob(contents) 
    infile.close()
    return blob

# %% [markdown]
# Now, instead of having to open a file, read the contents and close the file, we can just call the function read_file to do all that:

# %%
text = read_file("data/OliverTwist.txt")
#print(text)

# %% [markdown]
# At this point, you might be a little confused about what we mean by "TextBlob objects." Without going into too much detail, this is a feature of object-oriented-programming, where we are interacting with special data structures called *objects*.
#
# All you really need to know now is that when we talk about TextBlob objects, what we really mean are pieces of text that have been converted into a TextBlob, which means we can call the build-in TextBlob functions (or methods) on this object, as we do with the line: `blob.translate(to="es")` where we call the method `translate` on the TextBlob object named `blob`.

# %% [markdown]
# > Now that we have an easy-to-use function for creating our TextBlobs, we can start learning some new functionality.

# %% [markdown]
# # Word & Noun Phrase Frequencies

# %% [markdown]
# TextBlob makes it easy to calculate the [frequencies of words and noun phrases](http://textblob.readthedocs.io/en/dev/quickstart.html#get-word-and-noun-phrase-frequencies) without needing to build our own functions, as we did in the previous lessons.
#
# For example, to calcuate how many times the word "Oliver" (case insensitive) appears in our `text` TextBlob, we can use the following line of code:

# %%
# find single word count, using lowercase for our search
text.word_counts['oliver']
# Out:
# 876

# %% [markdown]
# >**Wait, didn't we recieve a different word count in our previous exercise?**
# Why do you think this could be?

# %% [markdown]
# We can also use the same basic functionality to retrieve frequencies of **all** words in the form of a dictionary:

# %%
text.word_counts
# Out:
# defaultdict(int,
#             {'ï»¿the': 1,
#              'project': 87,
#              'gutenberg': 30,
#              'ebook': 11,
#              'of': 3989,
#              'oliver': 876,
#              'twist': 68,
#              'by': 799,
#              'charles': 10,
#              'dickens': 4,
#              'this': 853,
#              'is': 784,
#              'for': 1182,
#              'the': 9807,
#              'use': 41,
#              'anyone': 5,
#              'anywhere': 5,
#              'at': 1010,
#              'no': 599,
#              'cost': 8,
#              'and': 5465,
#              'with': 1619,
#              'almost': 70,
#              'restrictions': 2,
#              'whatsoever': 4,
#              'you': 1823,
#              'may': 144,
#              'copy': 13,
#              'it': 1892,
#              'give': 87,
#              'away': 192,
#              'or': 579,
#              're-use': 2,
#              'under': 107,
#              'terms': 28,
#              'license': 16,
#              'included': 3,
#              'online': 4,
#              'www.gutenberg.net': 4,
#              'title': 1,
#              'author': 4,
#              'posting': 1,
#              'date': 7,
#              'october': 1,
#              '10': 1,
#              '2008': 1,
#              '730': 1,
#              'release': 3,
#              'november': 1,
#              '1996': 1,
#              'language': 1,
#              'english': 5,
#              'start': 14,
#              'produced': 13,
#              'peggy': 2,
#              'gaugy': 2,
#              'leigh': 2,
#              'little': 277,
#              'html': 2,
#              'version': 3,
#              'al': 2,
#              'haines': 2,
#              'parish': 33,
#              'boy': 301,
#              's': 1121,
#              'progress': 10,
#              'contents': 15,
#              'i': 1859,
#              'treats': 8,
#              'place': 121,
#              'where': 204,
#              'was': 1808,
#              'born': 22,
#              'circumstances': 23,
#              'attending': 3,
#              'his': 2357,
#              'birth': 18,
#              'ii': 2,
#              'growth': 5,
#              'education': 2,
#              'board': 41,
#              'iii': 2,
#              'relates': 6,
#              'how': 168,
#              'very': 495,
#              'near': 50,
#              'getting': 16,
#              'a': 3817,
#              'which': 896,
#              'would': 447,
#              'not': 839,
#              'have': 786,
#              'been': 464,
#              'sinecure': 2,
#              'iv': 2,
#              'being': 200,
#              'offered': 12,
#              'another': 124,
#              'makes': 17,
#              'first': 166,
#              'entry': 3,
#              'into': 464,
#              'public': 33,
#              'life': 114,
#              'v': 2,
#              'mingles': 2,
#              'new': 85,
#              'associates': 7,
#              'going': 77,
#              'to': 3964,
#              'funeral': 7,
#              'time': 325,
#              'he': 2496,
#              'forms': 6,
#              'an': 396,
#              'unfavourable': 4,
#              'notion': 4,
#              "master's": 1,
#              'business': 51,
#              'vi': 2,
#              'goaded': 4,
#              'taunts': 5,
#              'noah': 135,
#              'rouses': 2,
#              'action': 22,
#              'rather': 82,
#              'astonishes': 2,
#              'him': 1071,
#              'vii': 2,
#              'continues': 2,
#              'refractory': 2,
#              'viii': 2,
#              'walks': 10,
#              'london': 52,
#              'encounters': 2,
#              'on': 954,
#              'road': 41,
#              'strange': 35,
#              'sort': 21,
#              'young': 289,
#              'gentleman': 333,
#              'ix': 2,
#              'containing': 10,
#              'further': 29,
#              'particulars': 8,
#              'concerning': 11,
#              'pleasant': 24,
#              'old': 448,
#              'hopeful': 3,
#              'pupils': 8,
#              'x': 2,
#              'becomes': 5,
#              'better': 118,
#              'acquainted': 14,
#              'characters': 10,
#              'purchases': 2,
#              'experience': 10,
#              'high': 32,
#              'price': 5,
#              'short': 78,
#              'but': 734,
#              'important': 11,
#              'chapter': 63,
#              'in': 2438,
#              'history': 30,
#              'xi': 2,
#              'mr': 1081,
#              'fang': 35,
#              'police': 8,
#              'magistrate': 18,
#              'furnishes': 2,
#              'slight': 22,
#              'specimen': 3,
#              'mode': 11,
#              'administering': 4,
#              'justice': 20,
#              'xii': 2,
#              'taken': 73,
#              'care': 51,
#              'than': 245,
#              'ever': 87,
#              'before': 270,
#              'narrative': 7,
#              'reverts': 4,
#              'merry': 19,
#              'youthful': 6,
#              'friends': 48,
#              'xiii': 2,
#              'some': 396,
#              'acquaintances': 3,
#              'are': 344,
#              'introduced': 4,
#              'intelligent': 3,
#              'reader': 15,
#              'connected': 9,
#              'whom': 68,
#              'various': 22,
#              'matters': 20,
#              'related': 8,
#              'appertaining': 2,
#              'xiv': 2,
#              'comprising': 2,
#              'stay': 16,
#              'brownlow': 171,
#              'remarkable': 13,
#              'prediction': 5,
#              'one': 464,
#              'grimwig': 66,
#              'uttered': 24,
#              'when': 497,
#              'went': 95,
#              'out': 400,
#              'errand': 7,
#              'xv': 2,
#              'showing': 12,
#              'fond': 16,
#              'jew': 322,
#              'miss': 45,
#              'nancy': 118,
#              'were': 556,
#              'xvi': 2,
#              'what': 550,
#              'became': 21,
#              'after': 224,
#              'had': 1238,
#              'claimed': 3,
#              'xvii': 2,
#              'destiny': 3,
#              'continuing': 5,
#              'unpropitious': 3,
#              'brings': 8,
#              'great': 236,
#              'man': 390,
#              'injure': 3,
#              'reputation': 5,
#              'xviii': 2,
#              'passed': 75,
#              'improving': 4,
#              'society': 20,
#              'reputable': 2,
#              'xix': 2,
#              'notable': 3,
#              'plan': 5,
#              'discussed': 2,
#              'determined': 20,
#              'xx': 2,
#              'wherein': 10,
#              'delivered': 13,
#              'over': 224,
#              'william': 6,
#              'sikes': 352,
#              'xxi': 2,
#              'expedition': 14,
#              'xxii': 2,
#              'burglary': 4,
#              'xxiii': 2,
#              'contains': 4,
#              'substance': 6,
#              'conversation': 40,
#              'between': 77,
#              'bumble': 394,
#              'lady': 226,
#              'shows': 7,
#              'that': 1972,
#              'even': 124,
#              'beadle': 93,
#              'be': 795,
#              'susceptible': 3,
#              'points': 7,
#              'xxiv': 2,
#              'poor': 97,
#              'subject': 33,
#              'found': 56,
#              'importance': 14,
#              'xxv': 2,
#              'fagin': 308,
#              'company': 37,
#              'xxvi': 2,
#              'mysterious': 9,
#              'character': 18,
#              'appears': 6,
#              'upon': 481,
#              'scene': 25,
#              'many': 140,
#              'things': 43,
#              'inseparable': 3,
#              'from': 646,
#              'done': 113,
#              'performed': 10,
#              'xxvii': 2,
#              'atones': 2,
#              'unpoliteness': 2,
#              'former': 29,
#              'deserted': 9,
#              'most': 123,
#              'unceremoniously': 2,
#              'xxviii': 2,
#              'looks': 26,
#              'proceeds': 2,
#              'adventures': 6,
#              'xxix': 2,
#              'has': 176,
#              'introductory': 4,
#              'account': 24,
#              'inmates': 10,
#              'house': 133,
#              'resorted': 5,
#              'xxx': 2,
#              'visitors': 6,
#              'thought': 107,
#              'xxxi': 2,
#              'involves': 2,
#              'critical': 6,
#              'position': 27,
#              'xxxii': 2,
#              'happy': 49,
#              'began': 60,
#              'lead': 15,
#              'kind': 49,
#              'xxxiii': 2,
#              'happiness': 28,
#              'experiences': 2,
#              'sudden': 24,
#              'check': 6,
#              'xxxiv': 2,
#              'relative': 5,
#              'who': 527,
#              'now': 281,
#              'arrives': 6,
#              'adventure': 4,
#              'happened': 19,
#              'xxxv': 2,
#              'unsatisfactory': 2,
#              'result': 12,
#              'harry': 59,
#              'maylie': 99,
#              'rose': 205,
#              'xxxvi': 2,
#              'appear': 12,
#              'its': 142,
#              'should': 201,
#              'read': 32,
#              'notwithstanding': 15,
#              'as': 1334,
#              'sequel': 5,
#              'last': 103,
#              'key': 20,
#              'will': 309,
#              'follow': 22,
#              'xxxvii': 2,
#              'perceive': 2,
#              'contrast': 3,
#              'uncommon': 11,
#              'matrimonial': 3,
#              'cases': 9,
#              'xxxviii': 2,
#              'mrs': 265,
#              'monks': 139,
#              'their': 301,
#              'nocturnal': 2,
#              'interview': 16,
#              'xxxix': 2,
#              'introduces': 2,
#              'respectable': 11,
#              'already': 46,
#              'laid': 30,
#              'worthy': 22,
#              'heads': 21,
#              'together': 66,
#              'xl': 2,
#              'chamber': 11,
#              'xli': 2,
#              'fresh': 21,
#              'discoveries': 2,
#              'suprises': 2,
#              'like': 167,
#              'misfortunes': 4,
#              'seldom': 5,
#              'come': 256,
#              'alone': 61,
#              'xlii': 2,
#              'acquaintance': 12,
#              'exhibiting': 2,
#              'decided': 8,
#              'marks': 9,
#              'genius': 6,
#              'metropolis': 4,
#              'xliii': 2,
#              'shown': 5,
#              'artful': 24,
#              'dodger': 120,
#              'got': 127,
#              'trouble': 25,
#              'xliv': 2,
#              'redeem': 3,
#              'her': 789,
#              'pledge': 6,
#              'she': 591,
#              'fails': 6,
#              'xlv': 2,
#              'claypole': 53,
#              'employed': 8,
#              'secret': 22,
#              'mission': 9,
#              'xlvi': 2,
#              'appointment': 6,
#              'kept': 42,
#              'xlvii': 2,
#              'fatal': 3,
#              'consequences': 7,
#              'xlviii': 2,
#              'flight': 14,
#              'xlix': 2,
#              'length': 69,
#              'meet': 12,
#              'intelligence': 27,
#              'interrupts': 2,
#              'l': 2,
#              'pursuit': 12,
#              'escape': 12,
#              'li': 2,
#              'affording': 3,
#              'explanation': 10,
#              'more': 357,
#              'mysteries': 3,
#              'comprehending': 3,
#              'proposal': 6,
#              'marriage': 4,
#              'word': 89,
#              'settlement': 5,
#              'pin-money': 2,
#              'lii': 2,
#              'night': 150,
#              'alive': 25,
#              'liii': 2,
#              'among': 57,
#              'other': 250,
#              'buildings': 4,
#              'certain': 29,
#              'town': 40,
#              'reasons': 10,
#              'prudent': 5,
#              'refrain': 1,
#              'mentioning': 2,
#              'assign': 2,
#              'fictitious': 1,
#              'name': 81,
#              'there': 568,
#              'anciently': 1,
#              'common': 27,
#              'towns': 1,
#              'small': 82,
#              'wit': 1,
#              'workhouse': 39,
#              'day': 125,
#              'need': 38,
#              'myself': 30,
#              'repeat': 9,
#              'inasmuch': 6,
#              'can': 202,
#              'possible': 28,
#              'consequence': 14,
#              'stage': 6,
#              'all': 626,
#              'events': 12,
#              'item': 2,
#              'mortality': 1,
#              'whose': 49,
#              'prefixed': 1,
#              'head': 223,
#              'long': 157,
#              'ushered': 3,
#              'world': 44,
#              'sorrow': 10,
#              'surgeon': 15,
#              'remained': 37,
#              'matter': 63,
#              'considerable': 17,
#              'doubt': 22,
#              'whether': 69,
#              'child': 118,
#              'survive': 2,
#              'bear': 35,
#              'any': 269,
#              'case': 29,
#              'somewhat': 13,
#              'probable': 6,
#              'these': 191,
#              'memoirs': 1,
#              'never': 193,
#              'appeared': 54,
#              'if': 624,
#              'they': 725,
#              'comprised': 2,
#              'within': 54,
#              'couple': 25,
#              'pages': 6,
#              'possessed': 8,
#              'inestimable': 1,
#              'merit': 2,
#              'concise': 1,
#              'faithful': 5,
#              'biography': 1,
#              'extant': 1,
#              'literature': 1,
#              'age': 22,
#              'country': 33,
#              'although': 52,
#              'am': 127,
#              'disposed': 23,
#              'maintain': 2,
#              'itself': 32,
#              'fortunate': 5,
#              'enviable': 1,
#              'circumstance': 13,
#              'possibly': 11,
#              'befall': 1,
#              'human': 10,
#              'do': 629,
#              'mean': 72,
#              'say': 195,
#              'particular': 27,
#              'instance': 6,
#              'best': 53,
#              'thing': 59,
#              'could': 300,
#              'possibility': 5,
#              'occurred': 14,
#              'fact': 30,
#              'difficulty': 15,
#              'inducing': 1,
#              'take': 147,
#              'himself': 270,
#              'office': 35,
#              'respiration': 1,
#              'troublesome': 5,
#              'practice': 4,
#              'custom': 8,
#              'rendered': 23,
#              'necessary': 22,
#              'our': 76,
#              'easy': 12,
#              'existence': 6,
#              'lay': 62,
#              'gasping': 3,
#              'flock': 2,
#              'mattress': 5,
#              'unequally': 1,
#              'poised': 1,
#              'next': 60,
#              'balance': 4,
#              'decidedly': 5,
#              'favour': 12,
#              'latter': 22,
#              'during': 26,
#              'brief': 20,
#              'period': 6,
#              'surrounded': 9,
#              'careful': 8,
#              'grandmothers': 1,
#              'anxious': 25,
#              'aunts': 1,
#              'experienced': 9,
#              'nurses': 2,
#              'doctors': 3,
#              'profound': 11,
#              'wisdom': 6,
#              'inevitably': 2,
#              'indubitably': 1,
#              'killed': 3,
#              'nobody': 52,
#              'however': 47,
#              'pauper': 6,
#              'woman': 129,
#              'misty': 2,
#              'unwonted': 3,
#              'allowance': 5,
#              'beer': 14,
#              'did': 211,
#              'such': 193,
#              'contract': 5,
#              'nature': 36,
#              'fought': 4,
#              'point': 32,
#              'them': 367,
#              'few': 113,
#              'struggles': 9,
#              'breathed': 5,
#              'sneezed': 1,
#              'proceeded': 24,
#              'advertise': 1,
#              'burden': 2,
#              'having': 130,
#              'imposed': 4,
#              'setting': 8,
#              'up': 492,
#              'loud': 37,
#              'cry': 41,
#              'reasonably': 2,
#              'expected': 20,
#              'male': 9,
#              'infant': 10,
#              'useful': 6,
#              'appendage': 1,
#              'voice': 112,
#              'much': 202,
#              'longer': 19,
#              'space': 17,
#              'three': 100,
#              'minutes': 48,
#              'quarter': 20,
#              'gave': 55,
#              'proof': 17,
#              'free': 22,
#              'proper': 12,
#              'lungs': 3,
#              'patchwork': 1,
#              'coverlet': 2,
#              'carelessly': 9,
#              'flung': 9,
#              'iron': 19,
#              'bedstead': 4,
#              'rustled': 1,
#              'pale': 40,
#              'face': 175,
#              'raised': 46,
#              'feebly': 6,
#              'pillow': 9,
#              'faint': 9,
#              'imperfectly': 3,
#              'articulated': 1,
#              'words': 107,
#              'let': 131,
#              'me': 601,
#              'see': 216,
#              'die': 42,
#              'sitting': 31,
#              'turned': 119,
#              'towards': 94,
#              'fire': 72,
#              'giving': 22,
#              'palms': 2,
#              'hands': 124,
#              'warm': 15,
#              'rub': 7,
#              'alternately': 4,
#              'spoke': 57,
#              'advancing': 6,
#              'bed': 52,
#              'said': 1232,
#              'kindness': 6,
#              'might': 164,
#              'oh': 136,
#              'must': 139,
#              'talk': 35,
#              'about': 229,
#              'dying': 14,
#              'yet': 61,
#              'lor': 9,
#              'bless': 26,
#              'dear': 277,
#              'heart': 92,
#              'interposed': 30,
#              'nurse': 13,
#              'hastily': 44,
#              'depositing': 2,
#              'pocket': 37,
#              'green': 25,
#              'glass': 32,
#              'bottle': 13,
#              'tasting': 2,
#              'corner': 52,
#              'evident': 7,
#              'satisfaction': 16,
#              'lived': 14,
#              'sir': 210,
#              'thirteen': 2,
#              'children': 29,
#              'own': 136,
#              'em': 84,
#              'dead': 64,
#              'except': 26,
#              'two': 212,
#              'wurkus': 1,
#              'll': 193,
#              'know': 298,
#              'way': 208,
#              'think': 165,
#              'mother': 72,
#              'lamb': 3,
#              'apparently': 17,
#              'consolatory': 2,
#              'perspective': 1,
#              'prospects': 5,
#              'failed': 6,
#              'producing': 12,
#              'due': 4,
#              'effect': 29,
#              'patient': 12,
#              'shook': 34,
#              'stretched': 11,
#              'hand': 200,
#              'deposited': 7,
#              'arms': 36,
#              'imprinted': 2,
#              'cold': 68,
#              'white': 58,
#              'lips': 30,
#              'passionately': 6,
#              'forehead': 12,
#              'gazed': 10,
#              'wildly': 5,
#              'round': 153,
#              'shuddered': 2,
#              'fell': 63,
#              'back': 237,
#              'died': 38,
#              'chafed': 2,
#              'breast': 22,
#              'temples': 3,
#              'blood': 36,
#              'stopped': 53,
#              'forever': 2,
#              'talked': 9,
#              'hope': 68,
#              'comfort': 12,
#              'strangers': 7,
#              'too': 203,
#              'thingummy': 1,
#              'ah': 49,
#              'so': 594,
#              'picking': 9,
#              'cork': 1,
#              'fallen': 12,
#              'stooped': 7,
#              "n't": 622,
#              'mind': 122,
#              'sending': 9,
#              'cries': 9,
#              'putting': 29,
#              'gloves': 4,
#              'deliberation': 4,
#              'likely': 14,
#              'gruel': 13,
#              'put': 104,
#              'hat': 66,
#              'pausing': 10,
#              'bed-side': 1,
#              'door': 200,
#              'added': 35,
#              'good-looking': 2,
#              'girl': 232,
#              'brought': 79,
#              'here': 288,
#              'replied': 464,
#              'overseer': 5,
#              'order': 18,
#              'lying': 20,
#              'street': 75,
#              'walked': 73,
#              'distance': 36,
#              'shoes': 13,
#              'worn': 11,
#              'pieces': 8,
#              'came': 133,
#              'knows': 23,
#              'leaned': 4,
#              'body': 33,
#              'left': 128,
#              'story': 23,
#              'shaking': 27,
#              'wedding-ring': 2,
#              'good-night': 19,
#              'medical': 2,
#              'dinner': 13,
#              'once': 142,
#              'applied': 10,
#              'herself': 48,
#              'sat': 96,
#              'down': 282,
#              'low': 60,
#              'chair': 84,
#              'dress': 13,
#              'excellent': 6,
#              'example': 6,
#              'power': 32,
#              'wrapped': 10,
#              'blanket': 3,
#              'hitherto': 4,
#              'formed': 10,
#              'only': 195,
#              'covering': 7,
#              'nobleman': 1,
#              'beggar': 1,
#              'hard': 51,
#              'haughtiest': 1,
#              'stranger': 42,
#              'assigned': 1,
#              'station': 9,
#              'enveloped': 4,
#              'calico': 1,
#              'robes': 1,
#              'grown': 10,
#              'yellow': 5,
#              'same': 151,
#              'service': 11,
#              'badged': 1,
#              'ticketed': 1,
#              'orphan': 11,
#              'humble': 7,
#              'half-starved': 1,
#              'drudge': 2,
#              'cuffed': 1,
#              'buffeted': 1,
#              'through': 128,
#              'despised': 1,
#              'pitied': 4,
#              'none': 36,
#              'cried': 182,
#              'lustily': 1,
#              'known': 37,
#              'tender': 7,
#              'mercies': 1,
#              'church-wardens': 1,
#              'overseers': 1,
#              'perhaps': 57,
#              'louder': 9,
#              'eight': 13,
#              'ten': 32,
#              'months': 24,
#              'victim': 5,
#              'systematic': 1,
#              'course': 65,
#              'treachery': 2,
#              'deception': 1,
#              'hungry': 11,
#              'destitute': 4,
#              'situation': 13,
#              'duly': 1,
#              'reported': 3,
#              'authorities': 8,
#              'inquired': 111,
#              'dignity': 12,
#              'female': 17,
#              'then': 251,
#              'domiciled': 1,
#              'impart': 1,
#              'consolation': 5,
#              'nourishment': 2,
#              'stood': 61,
#              'humility': 8,
#              'magnanimously': 1,
#              'humanely': 1,
#              'resolved': 16,
#              'farmed': 1,
#              'dispatched': 3,
#              'branch-workhouse': 1,
#              'miles': 16,
#              'off': 139,
#              'twenty': 23,
#              'thirty': 5,
#              'juvenile': 3,
#              'offenders': 1,
#              'against': 82,
#              'poor-laws': 2,
#              'rolled': 13,
#              'floor': 41,
#              'without': 163,
#              'inconvenience': 1,
#              'food': 12,
#              'clothing': 2,
#              'parental': 1,
#              'superintendence': 1,
#              'elderly': 6,
#              'received': 25,
#              'culprits': 1,
#              'consideration': 18,
#              'sevenpence-halfpenny': 3,
#              'per': 4,
#              'week': 21,
#              'worth': 21,
#              'good': 212,
#              'diet': 2,
#              'deal': 47,
#              'quite': 94,
#              'enough': 105,
#              'overload': 1,
#              'stomach': 2,
#              'make': 129,
#              'uncomfortable': 4,
#              'knew': 64,
#              'accurate': 1,
#              'perception': 2,
#              'appropriated': 1,
#              'greater': 15,
#              'part': 61,
#              'weekly': 1,
#              'stipend': 2,
#              'consigned': 5,
#              'rising': 20,
#              'parochial': 9,
#              'generation': 1,
#              'shorter': 3,
#              'originally': 3,
#              'provided': 8,
#              'thereby': 5,
#              'finding': 16,
#              'lowest': 9,
#              'depth': 3,
#              'deeper': 6,
#              'still': 95,
#              'proving': 2,
#              'experimental': 3,
#              'philosopher': 5,
#              'everybody': 15,
#              'theory': 2,
#              'horse': 10,
#              'able': 29,
#              'live': 20,
#              'eating': 10,
#              'demonstrated': 4,
#              'well': 225,
#              'straw': 4,
#              'unquestionably': 1,
#              'spirited': 2,
#              'rampacious': 1,
#              'animal': 11,
#              'nothing': 119,
#              'four-and-twenty': 1,
#              'hours': 29,
#              'comfortable': 10,
#              'bait': 2,
#              'air': 72,
#              'unfortunately': 6,
#              'philosophy': 3,
#              'protecting': 2,
#              'similar': 6,
#              'usually': 9,
#              'attended': 5,
#              'operation': 4,
#              'system': 6,
#              'moment': 84,
#              'contrived': 4,
#              'exist': 3,
#              'smallest': 9,
#              'portion': 10,
#              'weakest': 1,
#              'perversely': 1,
#              'happen': 5,
#              'half': 66,
#              'either': 31,
#              'sickened': 1,
#              'want': 72,
#              'neglect': 6,
#              'half-smothered': 2,
#              'accident': 4,
#              'miserable': 11,
#              'summoned': 3,
#              'gathered': 6,
#              'fathers': 1,
#              'occasionally': 9,
#              'interesting': 8,
#              'inquest': 3,
#              'overlooked': 1,
#              'turning': 73,
#              'inadvertently': 1,
#              'scalded': 2,
#              'death': 56,
#              'washing': 6,
#              'though': 77,
#              'scarce': 3,
#              'anything': 78,
#              'approaching': 7,
#              'rare': 4,
#              'occurrence': 5,
#              'farm': 5,
#              'jury': 6,
#              'ask': 29,
#              'questions': 9,
#              'parishioners': 1,
#              'rebelliously': 1,
#              'affix': 1,
#              'signatures': 1,
#              'remonstrance': 3,
#              'impertinences': 1,
#              'speedily': 5,
#              'checked': 7,
#              'evidence': 10,
#              'testimony': 6,
#              'always': 56,
#              'opened': 46,
#              'inside': 20,
#              'indeed': 95,
#              'invariably': 3,
#              'swore': 6,
#              'whatever': 14,
#              'wanted': 28,
#              'self-devotional': 1,
#              'besides': 30,
#              'made': 187,
#              ...})

# %% [markdown]
# We can do something similar with noun phrases:

# %%
# to find the frequency of a single noun phrase:
text.np_counts['mr. bumble']

# %% [markdown]
# The below will retrieve frequencies of **all** noun phrases in the form of a dictionary...note that this may take a minute or two to run!

# %%
# to retrieve the frequencies of all noun phrases as a dictionary

text.np_counts

# %% [markdown]
# ### Quiz 2: write a function that takes a list of terms and a TextBlob to search and returns a dictionary with each term as a key and the frequency of each term as the value.

# %%
def word_counter(blob, mylist):
    "return dictionary of word frequencies"
    # Enter your code here:
    
    
    myDict = {}
    for word in mylist:
        myDict[word] = blob.word_counts[word]
    return myDict

list_to_search = ["family", "brother", "mother", "child"]
word_counter(text, list_to_search)
# Out:
# {'brother': 15, 'child': 118, 'family': 18, 'mother': 72}

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# From [Wikipedia](https://en.wikipedia.org/wiki/Sentiment_analysis):
#
# Sentiment analysis "refers to the use of natural language processing, text analysis, computational linguistics, and biometrics to systematically identify, extract, quantify, and study affective states and subjective information...
#
# A basic task in sentiment analysis is classifying the polarity of a given text at the document, sentence, or feature/aspect level—whether the expressed opinion in a document, a sentence or an entity feature/aspect is positive, negative, or neutral."

# %%
# What do you think this will return?
text.sentiment
# Out:
# Sentiment(polarity=0.08548031384868306, subjectivity=0.49169707194251144)

# %% [markdown]
# The [sentiment](http://textblob.readthedocs.io/en/dev/api_reference.html#textblob.blob.TextBlob.sentiment) method returns two values: polarity and subjectivity. The polarity score is a float within the range [-1.0, 1.0], where -1.0 is very negative and 1.0 is very positive.
#
# The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.
#
# Note that these values are returned in the form of a tuple, which is very similar to a list.
#
# We can also pull just the polarity or the subjectivity scores:

# %%
# try running the code below

print("The polarity is " + str(text.sentiment[0]))
print("The subjectivity is " + str(text.sentiment[1]))
# Out:
# The polarity is 0.08548031384868306
# The subjectivity is 0.49169707194251144

# %% [markdown]
# In this example, we print the individual polarity and subjectivity values by referring to their respective indicies and changing them to strings with the `str()` function.

# %% [markdown]
# -----

# %% [markdown]
# ### Quiz #3: In the cell below, determine the polarity and subjectivity of at least two Dickens novels. See if you can find the most positive and most negative.

# %%
# enter your code below

text2 = read_file("data/BleakHouse.txt")
text2.sentiment

# %% [markdown]
# ---

# %% [markdown]
# ## What if we want to look at individual sentences?

# %% [markdown]
# [TextBlob also supports tokenization](http://textblob.readthedocs.io/en/dev/quickstart.html#tokenization), or breaking a text into words or sentences.
#
# For sentence tokenization, TextBlob gives us a method called `sentences` that can be used to break a larger corpus into individual sentences. This can be used on its own, but we can also combine it with the sentiment analysis skills we've been building.

# %%
# try running the code below

for sentence in text.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.09375, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1290909090909091, subjectivity=0.34363636363636363)
# Sentiment(polarity=0.175, subjectivity=0.21666666666666667)
# Sentiment(polarity=0.24218855218855218, subjectivity=0.4790235690235691)
# Sentiment(polarity=0.21333333333333335, subjectivity=0.4916666666666667)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.24789772727272727, subjectivity=0.6250757575757575)
# Sentiment(polarity=0.1785353535353535, subjectivity=0.5133030303030303)
# Sentiment(polarity=-0.5, subjectivity=0.3)
# Sentiment(polarity=-0.4, subjectivity=0.7)
# Sentiment(polarity=0.14566326530612245, subjectivity=0.4211734693877552)
# Sentiment(polarity=0.15833333333333333, subjectivity=0.44166666666666665)
# Sentiment(polarity=0.2505952380952381, subjectivity=0.5172619047619048)
# Sentiment(polarity=0.057638888888888885, subjectivity=0.46388888888888885)
# Sentiment(polarity=0.10416666666666669, subjectivity=0.7166666666666666)
# Sentiment(polarity=0.05, subjectivity=0.35)
# Sentiment(polarity=0.09079545454545454, subjectivity=0.33181818181818185)
# Sentiment(polarity=-0.09555555555555556, subjectivity=0.5348148148148149)
# Sentiment(polarity=0.3, subjectivity=0.3)
# Sentiment(polarity=0.27499999999999997, subjectivity=0.5625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.024999999999999994, subjectivity=0.275)
# Sentiment(polarity=0.24374999999999997, subjectivity=0.575)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=-0.19166666666666665, subjectivity=0.3416666666666666)
# Sentiment(polarity=-0.05, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.21250000000000002, subjectivity=0.5625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=-0.5, subjectivity=0.6)
# Sentiment(polarity=-0.2, subjectivity=0.3)
# Sentiment(polarity=-0.5, subjectivity=0.6)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.13333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.02888888888888888, subjectivity=0.2777777777777778)
# Sentiment(polarity=0.5625, subjectivity=0.7)
# Sentiment(polarity=-0.09722222222222222, subjectivity=0.5472222222222222)
# Sentiment(polarity=-0.025, subjectivity=0.18125000000000002)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.025000000000000005, subjectivity=0.016666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.049999999999999996, subjectivity=0.28095238095238095)
# Sentiment(polarity=0.18333333333333335, subjectivity=0.5583333333333333)
# Sentiment(polarity=0.48000000000000004, subjectivity=0.5475000000000001)
# Sentiment(polarity=0.4916666666666667, subjectivity=0.75)
# Sentiment(polarity=0.55, subjectivity=0.6875)
# Sentiment(polarity=0.36453423120089784, subjectivity=0.6330246913580245)
# Sentiment(polarity=-0.21027777777777779, subjectivity=0.5455555555555556)
# Sentiment(polarity=0.21428571428571427, subjectivity=0.3321428571428572)
# Sentiment(polarity=0.1, subjectivity=0.15)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.49583333333333335, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.16666666666666669, subjectivity=0.7)
# Sentiment(polarity=-0.2866666666666667, subjectivity=0.47666666666666674)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.07916666666666666, subjectivity=0.6291666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.2)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.125, subjectivity=0.4)
# Sentiment(polarity=0.625, subjectivity=1.0)
# Sentiment(polarity=0.07291666666666666, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.39999999999999997)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.43333333333333335, subjectivity=0.8796296296296297)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=0.6, subjectivity=0.2)
# Sentiment(polarity=0.6, subjectivity=0.2)
# Sentiment(polarity=0.6, subjectivity=0.2)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.007142857142857145, subjectivity=0.6178571428571429)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.39375, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.17152777777777778, subjectivity=0.3944444444444445)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.1, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.5)
# Sentiment(polarity=0.125, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.725)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3076923076923077, subjectivity=0.5769230769230769)
# Sentiment(polarity=0.3, subjectivity=0.5499999999999999)
# Sentiment(polarity=0.1923076923076923, subjectivity=0.7692307692307692)
# Sentiment(polarity=0.31, subjectivity=0.5066666666666667)
# Sentiment(polarity=0.37777777777777777, subjectivity=0.4388888888888889)
# Sentiment(polarity=0.09305555555555556, subjectivity=0.5111111111111111)
# Sentiment(polarity=-0.3666666666666667, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.060416666666666674, subjectivity=0.6138888888888889)
# Sentiment(polarity=-0.084375, subjectivity=0.42500000000000004)
# Sentiment(polarity=0.0, subjectivity=0.43333333333333335)
# Sentiment(polarity=0.05, subjectivity=0.1)
# Sentiment(polarity=0.19516233766233765, subjectivity=0.4174404761904762)
# Sentiment(polarity=0.030129870129870128, subjectivity=0.26571428571428574)
# Sentiment(polarity=0.13133333333333333, subjectivity=0.37066666666666664)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.39999999999999997)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.195)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.5)
# Sentiment(polarity=-0.2, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4666666666666667, subjectivity=0.9444444444444444)
# Sentiment(polarity=-0.2, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.14285714285714285, subjectivity=0.3011904761904762)
# Sentiment(polarity=0.22499999999999998, subjectivity=0.22500000000000003)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.22999999999999998, subjectivity=0.26999999999999996)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.03547619047619048, subjectivity=0.40547619047619043)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.6)
# Sentiment(polarity=0.2625, subjectivity=0.485)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.049999999999999996, subjectivity=0.4333333333333333)
# Sentiment(polarity=-0.05, subjectivity=0.15256410256410258)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=-0.033333333333333354, subjectivity=0.55)
# Sentiment(polarity=-0.2722222222222222, subjectivity=0.47222222222222227)
# Sentiment(polarity=0.35, subjectivity=0.6624999999999999)
# Sentiment(polarity=0.25, subjectivity=0.2833333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3, subjectivity=0.44166666666666665)
# Sentiment(polarity=-0.13173076923076923, subjectivity=0.3256410256410256)
# Sentiment(polarity=-0.4, subjectivity=0.8500000000000001)
# Sentiment(polarity=0.21428571428571427, subjectivity=0.42857142857142855)
# Sentiment(polarity=0.4, subjectivity=0.4083333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.24154761904761904, subjectivity=0.5247619047619048)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=-0.19687500000000002, subjectivity=0.3989583333333333)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15, subjectivity=0.46666666666666673)
# Sentiment(polarity=-0.0625, subjectivity=0.1875)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=0.5666666666666667, subjectivity=0.8166666666666668)
# Sentiment(polarity=0.11349999999999999, subjectivity=0.367)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.48000000000000004, subjectivity=0.645)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=0.05000000000000002, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3, subjectivity=0.3)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.2388888888888889)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=0.25, subjectivity=0.25)
# Sentiment(polarity=-0.17142857142857146, subjectivity=0.5119047619047619)
# Sentiment(polarity=0.16, subjectivity=0.47333333333333333)
# Sentiment(polarity=0.11499999999999999, subjectivity=0.3916666666666667)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=-0.19464285714285715, subjectivity=0.5821428571428572)
# Sentiment(polarity=0.0, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.975)
# Sentiment(polarity=-0.0625, subjectivity=0.22083333333333333)
# Sentiment(polarity=0.237012987012987, subjectivity=0.5042207792207791)
# Sentiment(polarity=0.12374603174603174, subjectivity=0.520063492063492)
# Sentiment(polarity=0.2833333333333333, subjectivity=0.35000000000000003)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.052083333333333336, subjectivity=0.75)
# Sentiment(polarity=0.17916666666666667, subjectivity=0.5833333333333333)
# Sentiment(polarity=0.215, subjectivity=0.77)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.10555555555555557, subjectivity=0.5666666666666667)
# Sentiment(polarity=0.22083333333333333, subjectivity=0.31666666666666665)
# Sentiment(polarity=0.2875, subjectivity=0.47500000000000003)
# Sentiment(polarity=0.25, subjectivity=0.25)
# Sentiment(polarity=0.2, subjectivity=0.1)
# Sentiment(polarity=0.15, subjectivity=0.05)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4238095238095238, subjectivity=0.5404761904761906)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.04062500000000001, subjectivity=0.2583333333333333)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=-0.10370370370370373, subjectivity=0.525925925925926)
# Sentiment(polarity=0.1361111111111111, subjectivity=0.6847222222222222)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13, subjectivity=0.13)
# Sentiment(polarity=-0.1, subjectivity=0.2)
# Sentiment(polarity=0.31, subjectivity=0.7133333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=-0.12666666666666665, subjectivity=0.5066666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=-0.48888888888888893, subjectivity=0.4888888888888889)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3458333333333333, subjectivity=0.5708333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.06666666666666667, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.45)
# Sentiment(polarity=-0.4458333333333333, subjectivity=0.7708333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.7)
# Sentiment(polarity=-0.625, subjectivity=0.875)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0833333333333333, subjectivity=0.5366666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13333333333333333, subjectivity=0.19999999999999998)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=-0.0236111111111111, subjectivity=0.7333333333333334)
# Sentiment(polarity=0.18944444444444444, subjectivity=0.8472222222222222)
# Sentiment(polarity=0.27777777777777773, subjectivity=0.43333333333333335)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.34166666666666673, subjectivity=0.65)
# Sentiment(polarity=-0.413888888888889, subjectivity=0.5972222222222222)
# Sentiment(polarity=-0.20833333333333331, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.15000000000000002, subjectivity=0.2)
# Sentiment(polarity=0.10714285714285714, subjectivity=0.5357142857142857)
# Sentiment(polarity=0.22533333333333333, subjectivity=0.5386666666666666)
# Sentiment(polarity=-0.09375, subjectivity=0.25)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5666666666666668)
# Sentiment(polarity=0.25, subjectivity=0.6)
# Sentiment(polarity=0.5071428571428571, subjectivity=0.5892857142857143)
# Sentiment(polarity=-0.16875, subjectivity=0.41874999999999996)
# Sentiment(polarity=-0.1125, subjectivity=0.3375)
# Sentiment(polarity=-0.029166666666666664, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.043750000000000004, subjectivity=0.24374999999999997)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.05, subjectivity=0.1)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.35, subjectivity=0.55)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.3942307692307692)
# Sentiment(polarity=-0.20972222222222223, subjectivity=0.42916666666666664)
# Sentiment(polarity=-0.7, subjectivity=1.0)
# Sentiment(polarity=0.13333333333333333, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.8)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.0024999999999999953, subjectivity=0.30125)
# Sentiment(polarity=0.11481481481481481, subjectivity=0.4962962962962963)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.05499999999999999, subjectivity=0.19)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15625, subjectivity=0.4375)
# Sentiment(polarity=-0.6, subjectivity=0.9)
# Sentiment(polarity=-0.3833333333333333, subjectivity=0.4666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.75, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.05, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.25)
# Sentiment(polarity=0.2375, subjectivity=0.5375)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.008333333333333331, subjectivity=0.31666666666666665)
# Sentiment(polarity=0.3, subjectivity=0.45)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.14545454545454545, subjectivity=0.4340909090909091)
# Sentiment(polarity=0.39999999999999997, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# Sentiment(polarity=0.24300000000000002, subjectivity=0.43999999999999995)
# Sentiment(polarity=0.12333333333333332, subjectivity=0.52)
# Sentiment(polarity=0.19999999999999998, subjectivity=0.615)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.01388888888888889, subjectivity=0.3138888888888889)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.2791666666666667)
# Sentiment(polarity=0.03333333333333334, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.15625, subjectivity=0.75)
# Sentiment(polarity=0.375, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=-0.325, subjectivity=0.52)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4000000000000001, subjectivity=0.4166666666666667)
# Sentiment(polarity=0.28333333333333327, subjectivity=0.26666666666666666)
# Sentiment(polarity=0.10101010101010101, subjectivity=0.48484848484848486)
# Sentiment(polarity=-0.5, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.9)
# Sentiment(polarity=0.20833333333333331, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.6875)
# Sentiment(polarity=0.41, subjectivity=0.6166666666666666)
# Sentiment(polarity=0.09444444444444444, subjectivity=0.39444444444444443)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.1)
# Sentiment(polarity=-0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.8125, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.42142857142857143, subjectivity=0.8095238095238094)
# Sentiment(polarity=-0.004761904761904782, subjectivity=0.5273809523809524)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.44999999999999996, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.44642857142857145, subjectivity=0.5714285714285714)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.45499999999999996, subjectivity=0.8450000000000001)
# Sentiment(polarity=-0.4392857142857143, subjectivity=0.5428571428571429)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.125, subjectivity=0.3)
# Sentiment(polarity=-0.25, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.4712962962962963)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.45, subjectivity=0.475)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.14999999999999997, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.22857142857142856, subjectivity=0.3119047619047619)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.06666666666666667, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.11562499999999999, subjectivity=0.33749999999999997)
# Sentiment(polarity=0.3655555555555556, subjectivity=0.5344444444444444)
# Sentiment(polarity=-0.18035714285714288, subjectivity=0.7081632653061225)
# Sentiment(polarity=0.3324009324009324, subjectivity=0.5780885780885782)
# Sentiment(polarity=0.18250000000000002, subjectivity=0.49000000000000005)
# Sentiment(polarity=0.27180134680134677, subjectivity=0.49890572390572396)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4333333333333333, subjectivity=0.7333333333333333)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.00416666666666667, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# Sentiment(polarity=-0.24375000000000002, subjectivity=0.65)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.12499999999999997, subjectivity=0.7)
# Sentiment(polarity=-0.16249999999999998, subjectivity=0.9099999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# Sentiment(polarity=0.14444444444444443, subjectivity=0.43333333333333335)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.4666666666666666, subjectivity=0.5666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.19583333333333333, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.325, subjectivity=0.52)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.43333333333333335)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.3)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# Sentiment(polarity=-0.04022222222222223, subjectivity=0.2675555555555556)
# Sentiment(polarity=-0.37777777777777777, subjectivity=0.6444444444444445)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.9, subjectivity=1.0)
# Sentiment(polarity=-0.2333333333333333, subjectivity=0.43333333333333335)
# Sentiment(polarity=0.9, subjectivity=1.0)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.125, subjectivity=0.4375)
# Sentiment(polarity=-0.3, subjectivity=0.4083333333333334)
# Sentiment(polarity=0.6, subjectivity=0.9)
# Sentiment(polarity=-0.25, subjectivity=0.65)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.2435185185185185, subjectivity=0.3425925925925926)
# Sentiment(polarity=-0.2986111111111111, subjectivity=0.5388888888888889)
# Sentiment(polarity=0.09, subjectivity=0.3603846153846154)
# Sentiment(polarity=-0.0826569264069264, subjectivity=0.44002976190476184)
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.31666666666666665, subjectivity=0.31666666666666665)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.052500000000000005, subjectivity=0.41)
# Sentiment(polarity=0.05, subjectivity=0.34375)
# Sentiment(polarity=-0.13333333333333333, subjectivity=0.6166666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.7)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.75, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.24305555555555555, subjectivity=0.42986111111111114)
# Sentiment(polarity=0.0625, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.7)
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.015277777777777793, subjectivity=0.34444444444444444)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=-0.028571428571428564, subjectivity=0.4714285714285714)
# Sentiment(polarity=-0.1388888888888889, subjectivity=0.3555555555555555)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.0, subjectivity=0.3)
# Sentiment(polarity=-0.02777777777777779, subjectivity=0.34444444444444444)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.20625, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.425, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.060714285714285735, subjectivity=0.44285714285714284)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.07291666666666667, subjectivity=0.13541666666666666)
# Sentiment(polarity=-0.025, subjectivity=0.23333333333333334)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=0.7, subjectivity=1.0)
# Sentiment(polarity=0.2375, subjectivity=0.38125000000000003)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.057499999999999996, subjectivity=0.43999999999999995)
# Sentiment(polarity=-0.125, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.7000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.14666666666666664, subjectivity=0.45333333333333337)
# Sentiment(polarity=0.195, subjectivity=0.825)
# Sentiment(polarity=0.25238095238095243, subjectivity=0.6904761904761904)
# Sentiment(polarity=0.25, subjectivity=0.4)
# Sentiment(polarity=0.05, subjectivity=0.7)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.65, subjectivity=0.65)
# Sentiment(polarity=0.75, subjectivity=0.8)
# Sentiment(polarity=0.1, subjectivity=0.45)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=-0.10416666666666667, subjectivity=0.5881410256410257)
# Sentiment(polarity=0.17727272727272728, subjectivity=0.5909090909090909)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.09999999999999998, subjectivity=0.4166666666666667)
# Sentiment(polarity=0.14285714285714285, subjectivity=0.26785714285714285)
# Sentiment(polarity=0.025, subjectivity=0.4)
# Sentiment(polarity=0.009523809523809523, subjectivity=0.24904761904761905)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Sentiment(polarity=-0.2, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.10000000000000003, subjectivity=0.95)
# Sentiment(polarity=0.8, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=-0.9, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.18199999999999997, subjectivity=0.6116666666666666)
# Sentiment(polarity=0.21666666666666667, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1875, subjectivity=0.1)
# Sentiment(polarity=0.3190476190476191, subjectivity=0.4404761904761905)
# Sentiment(polarity=0.11249999999999999, subjectivity=0.65)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.45)
# Sentiment(polarity=-0.125, subjectivity=0.6166666666666667)
# Sentiment(polarity=-0.625, subjectivity=1.0)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=-0.06666666666666665, subjectivity=0.6333333333333333)
# Sentiment(polarity=0.08708333333333333, subjectivity=0.3858333333333333)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.1)
# Sentiment(polarity=-0.06507936507936508, subjectivity=0.6412698412698413)
# Sentiment(polarity=0.022936507936507925, subjectivity=0.2700396825396825)
# Sentiment(polarity=0.2333333333333333, subjectivity=0.4916666666666667)
# Sentiment(polarity=-0.06666666666666665, subjectivity=0.5527777777777777)
# Sentiment(polarity=-0.8, subjectivity=1.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.5266666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.5)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.5)
# Sentiment(polarity=-0.049999999999999996, subjectivity=0.20000000000000004)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3365, subjectivity=0.542)
# Sentiment(polarity=0.4, subjectivity=0.5)
# Sentiment(polarity=-0.6, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.05)
# Sentiment(polarity=0.05, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.475, subjectivity=0.8)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.20185185185185187, subjectivity=0.362962962962963)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3499999999999999, subjectivity=0.3833333333333333)
# Sentiment(polarity=-0.1875, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.3444444444444444)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.016666666666666663, subjectivity=0.5083333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2044642857142857, subjectivity=0.5125)
# Sentiment(polarity=0.7875, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.16285714285714284, subjectivity=0.6257142857142857)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.55, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.014444444444444446, subjectivity=0.2444444444444444)
# Sentiment(polarity=0.5625, subjectivity=0.25)
# Sentiment(polarity=-0.09999999999999999, subjectivity=0.4)
# Sentiment(polarity=0.41666666666666663, subjectivity=0.5)
# Sentiment(polarity=0.25, subjectivity=0.55)
# Sentiment(polarity=0.28809523809523807, subjectivity=0.5476190476190476)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=-0.38518518518518513, subjectivity=0.562962962962963)
# Sentiment(polarity=0.0, subjectivity=0.3)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.11410256410256409, subjectivity=0.4730769230769231)
# Sentiment(polarity=0.09148148148148146, subjectivity=0.4962962962962963)
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1777777777777778, subjectivity=0.19444444444444448)
# Sentiment(polarity=-0.06666666666666665, subjectivity=0.5666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.175, subjectivity=0.725)
# Sentiment(polarity=-0.07692307692307693, subjectivity=0.15384615384615385)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.26749999999999996, subjectivity=0.76)
# Sentiment(polarity=0.25, subjectivity=0.25)
# Sentiment(polarity=0.1, subjectivity=0.1)
# Sentiment(polarity=-0.05714285714285716, subjectivity=0.9285714285714286)
# Sentiment(polarity=0.20000000000000004, subjectivity=0.2833333333333333)
# Sentiment(polarity=0.43333333333333335, subjectivity=0.5)
# Sentiment(polarity=0.05231481481481481, subjectivity=0.42962962962962964)
# Sentiment(polarity=0.3833333333333333, subjectivity=0.525)
# Sentiment(polarity=0.2916666666666667, subjectivity=0.5303030303030304)
# Sentiment(polarity=0.6, subjectivity=0.7)
# Sentiment(polarity=0.3375, subjectivity=0.9625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8766666666666667, subjectivity=0.875)
# Sentiment(polarity=0.19663299663299663, subjectivity=0.5097643097643099)
# Sentiment(polarity=-0.075, subjectivity=0.725)
# Sentiment(polarity=-0.011666666666666659, subjectivity=0.5604166666666667)
# Sentiment(polarity=-0.3208333333333333, subjectivity=0.5687500000000001)
# Sentiment(polarity=0.25, subjectivity=0.6)
# Sentiment(polarity=0.4166666666666667, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=0.03888888888888889, subjectivity=0.7416666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.06666666666666665, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4325396825396825, subjectivity=0.5561507936507936)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.125, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.5625, subjectivity=0.5)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.16999999999999998, subjectivity=0.34)
# Sentiment(polarity=-0.055714285714285716, subjectivity=0.5641269841269841)
# Sentiment(polarity=-0.3499999999999999, subjectivity=0.3717948717948718)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.43333333333333335, subjectivity=0.65)
# Sentiment(polarity=-0.11666666666666663, subjectivity=0.4645299145299145)
# Sentiment(polarity=0.30166666666666664, subjectivity=0.6583333333333333)
# Sentiment(polarity=0.0, subjectivity=0.45)
# Sentiment(polarity=0.04444444444444443, subjectivity=0.5111111111111111)
# Sentiment(polarity=-0.39999999999999997, subjectivity=0.48888888888888893)
# Sentiment(polarity=0.34166666666666673, subjectivity=0.6499999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.17045454545454544, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.78125, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05109126984126984, subjectivity=0.31378968253968254)
# Sentiment(polarity=-0.234375, subjectivity=0.5)
# Sentiment(polarity=0.37777777777777777, subjectivity=0.5277777777777778)
# Sentiment(polarity=-0.234375, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1375, subjectivity=0.5375)
# Sentiment(polarity=0.09999999999999998, subjectivity=0.825)
# Sentiment(polarity=-0.2833333333333334, subjectivity=0.48888888888888893)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.075, subjectivity=0.7)
# Sentiment(polarity=-0.5, subjectivity=0.6)
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446)
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.125, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.43333333333333335)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.26, subjectivity=0.26)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2833333333333333, subjectivity=0.43333333333333335)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.10314814814814814, subjectivity=0.6768518518518518)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=-0.325, subjectivity=0.5833333333333333)
# Sentiment(polarity=0.024464285714285713, subjectivity=0.5407142857142857)
# Sentiment(polarity=0.03333333333333333, subjectivity=0.3666666666666667)
# Sentiment(polarity=-0.06666666666666668, subjectivity=0.4666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.15)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13333333333333333, subjectivity=0.3277777777777778)
# Sentiment(polarity=0.0, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15000000000000002, subjectivity=0.25)
# Sentiment(polarity=0.25571428571428567, subjectivity=0.5285714285714286)
# Sentiment(polarity=0.8049999999999999, subjectivity=0.6900000000000002)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=0.45)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.48333333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.6, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# ...
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=-0.39999999999999997, subjectivity=0.8333333333333333)
# Sentiment(polarity=-0.1, subjectivity=0.45)
# Sentiment(polarity=0.25, subjectivity=0.25)
# Sentiment(polarity=-0.05, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446)
# Sentiment(polarity=-0.2, subjectivity=0.1)
# Sentiment(polarity=0.128125, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=-0.195, subjectivity=0.52)
# Sentiment(polarity=0.16041666666666665, subjectivity=0.6229166666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.12870370370370368, subjectivity=0.5074074074074074)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.10250000000000001, subjectivity=0.61)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.15, subjectivity=0.55)
# Sentiment(polarity=-0.11762820512820514, subjectivity=0.339423076923077)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.1875, subjectivity=0.6875)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.05, subjectivity=0.225)
# Sentiment(polarity=0.4, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.22000000000000003, subjectivity=0.48)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.6, subjectivity=0.8)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.21212121212121213, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.009659090909090912, subjectivity=0.5983901515151515)
# Sentiment(polarity=-0.15625, subjectivity=0.4375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=-0.6666666666666666, subjectivity=0.6888888888888888)
# Sentiment(polarity=-0.20277777777777778, subjectivity=0.2694444444444445)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2511111111111111, subjectivity=0.5977777777777777)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.05833333333333333, subjectivity=0.3583333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=-0.05208333333333333, subjectivity=0.6791666666666667)
# Sentiment(polarity=-0.35, subjectivity=0.55)
# Sentiment(polarity=-0.059375, subjectivity=0.55)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.43333333333333335)
# Sentiment(polarity=-0.1, subjectivity=0.2)
# Sentiment(polarity=-0.008333333333333345, subjectivity=0.41666666666666663)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2833333333333334, subjectivity=0.3833333333333333)
# Sentiment(polarity=-0.2, subjectivity=0.1)
# Sentiment(polarity=-0.075, subjectivity=0.2)
# Sentiment(polarity=0.08333333333333333, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.06111111111111111, subjectivity=0.32222222222222224)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.06770833333333331, subjectivity=0.3635416666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15625, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.04999999999999999, subjectivity=0.525)
# Sentiment(polarity=0.15, subjectivity=0.31666666666666665)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.11833333333333333, subjectivity=0.22)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.2, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.025, subjectivity=0.25)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.005555555555555536, subjectivity=0.3944444444444445)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.033333333333333354, subjectivity=0.55)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.35, subjectivity=0.44999999999999996)
# Sentiment(polarity=-0.1, subjectivity=0.45)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.6)
# Sentiment(polarity=0.15625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.05)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0625, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.10000000000000002, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.7222222222222222)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.075, subjectivity=0.5083333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.6000000000000001, subjectivity=0.825)
# Sentiment(polarity=-0.15833333333333333, subjectivity=0.4166666666666667)
# Sentiment(polarity=-0.05, subjectivity=0.08333333333333334)
# Sentiment(polarity=-0.12916666666666668, subjectivity=0.319047619047619)
# Sentiment(polarity=0.3143939393939394, subjectivity=0.5299242424242424)
# Sentiment(polarity=0.6, subjectivity=0.45)
# Sentiment(polarity=0.1125, subjectivity=0.5599999999999999)
# Sentiment(polarity=0.225, subjectivity=0.42500000000000004)
# Sentiment(polarity=0.1649621212121212, subjectivity=0.3880681818181818)
# Sentiment(polarity=0.1, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.33035714285714285, subjectivity=0.5571428571428572)
# Sentiment(polarity=0.02666666666666666, subjectivity=0.5399999999999999)
# Sentiment(polarity=0.0, subjectivity=0.21666666666666667)
# Sentiment(polarity=0.08166666666666667, subjectivity=0.5283333333333333)
# Sentiment(polarity=0.3611111111111111, subjectivity=0.8333333333333334)
# Sentiment(polarity=0.21666666666666665, subjectivity=0.6166666666666667)
# Sentiment(polarity=0.65, subjectivity=0.625)
# Sentiment(polarity=0.3771428571428571, subjectivity=0.5971428571428572)
# Sentiment(polarity=0.28125, subjectivity=0.5)
# Sentiment(polarity=0.2503401360544218, subjectivity=0.295578231292517)
# Sentiment(polarity=0.22812500000000002, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.18333333333333332, subjectivity=0.26666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.6375000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.016666666666666666, subjectivity=0.10000000000000002)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.325)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.7333333333333333)
# Sentiment(polarity=0.04012987012987013, subjectivity=0.2751948051948052)
# Sentiment(polarity=0.17708333333333331, subjectivity=0.4354166666666667)
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# Sentiment(polarity=0.15, subjectivity=0.2333333333333333)
# Sentiment(polarity=0.27999999999999997, subjectivity=0.6200000000000001)
# Sentiment(polarity=0.13742897727272732, subjectivity=0.4364583333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3214876033057852, subjectivity=0.5049586776859504)
# Sentiment(polarity=0.6833333333333333, subjectivity=0.6708333333333334)
# Sentiment(polarity=0.05, subjectivity=0.1)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.024999999999999994, subjectivity=0.35)
# Sentiment(polarity=-0.2708333333333333, subjectivity=0.3458333333333333)
# Sentiment(polarity=-0.09375, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.18333333333333335)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.20357142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.5633333333333334, subjectivity=1.0)
# Sentiment(polarity=0.05, subjectivity=0.45)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.28750000000000003, subjectivity=0.5375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05000000000000002, subjectivity=0.5)
# Sentiment(polarity=0.3, subjectivity=0.4)
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.21666666666666665, subjectivity=0.3833333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.4625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.1)
# Sentiment(polarity=0.03333333333333333, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.05892857142857143, subjectivity=0.35059523809523807)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.2611111111111111, subjectivity=0.5027777777777778)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.41666666666666663)
# Sentiment(polarity=-0.0625, subjectivity=0.2125)
# Sentiment(polarity=0.0, subjectivity=0.05)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.11833333333333333, subjectivity=0.525)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.23333333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.11249999999999999, subjectivity=0.4625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2388888888888889, subjectivity=0.7166666666666668)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.6)
# Sentiment(polarity=-0.07142857142857144, subjectivity=0.43154761904761907)
# Sentiment(polarity=0.175, subjectivity=0.275)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.3)
# Sentiment(polarity=0.1, subjectivity=0.1)
# Sentiment(polarity=0.1, subjectivity=0.15000000000000002)
# Sentiment(polarity=0.07500000000000001, subjectivity=0.32500000000000007)
# Sentiment(polarity=0.35, subjectivity=0.55)
# Sentiment(polarity=-0.08125, subjectivity=0.2544642857142857)
# Sentiment(polarity=0.35, subjectivity=0.55)
# Sentiment(polarity=0.1375, subjectivity=0.5875)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.35)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.25833333333333336)
# Sentiment(polarity=-0.06904761904761905, subjectivity=0.46547619047619043)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.07785714285714286, subjectivity=0.2707142857142857)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.10714285714285714, subjectivity=0.3392857142857143)
# Sentiment(polarity=0.0, subjectivity=0.14285714285714285)
# Sentiment(polarity=0.8, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1825, subjectivity=0.4192857142857143)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.21428571428571427, subjectivity=0.5714285714285714)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.11249999999999999, subjectivity=0.42500000000000004)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.21212121212121213, subjectivity=0.48484848484848486)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13333333333333333, subjectivity=0.4000000000000001)
# Sentiment(polarity=0.125, subjectivity=0.2375)
# Sentiment(polarity=0.3, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1125, subjectivity=0.1125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.22499999999999998, subjectivity=0.325)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05357142857142856, subjectivity=0.34880952380952385)
# Sentiment(polarity=0.21666666666666667, subjectivity=0.6333333333333333)
# Sentiment(polarity=0.6, subjectivity=0.8)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.3833333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.08888888888888889, subjectivity=0.27777777777777773)
# Sentiment(polarity=0.0, subjectivity=0.025)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.4)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05000000000000002, subjectivity=0.5)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=-0.038461538461538464, subjectivity=0.6346153846153846)
# Sentiment(polarity=0.13333333333333333, subjectivity=0.35555555555555557)
# Sentiment(polarity=0.08333333333333333, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.20787878787878786, subjectivity=0.36848484848484847)

# %% [markdown]
# Okay...that's a lot of information. What we've done here is use TextBlob's built-in `sentences` method to break the text up into individual sentences. These sentences are then iterated over through our `for` loop, printing the `sentiment` for each.

# %% [markdown]
# But what can we do with this information? Now that we have computed a range of general statistics for our text, it would be nice to have a better way to visualize them. We could for example, plot for each sentence, what its polarity is and even graph the change in sentiment over the duration of the novel.
#
# Python is quite good at graphing or plotting. This isn't something that we'll tackle here due to time constraints, but if you're interested in experimenting after class, the plotting library *matplotlib* (see [here](http://matplotlib.org)) is very well supported and allows us to produce all kinds of graphs.
#
# What we'll do instead here, is learn how to export data from Python that we can use in a 3rd party program that we may be more comfortable with, such as MS Excel or Goolge Sheets.

# %% [markdown]
# > ### Exporting Data

# %% [markdown]
# To do this, let's first create a dictionary. This will allow us to add the polarity values of each sentence in the text to this dictionary, with the sentence number as the key and the polarity as the value.

# %%
# showing change in sentiment over the duration of the novel

sentiment_polarity_by_sentence = {}
counter = 0
for sentence in text.sentences:
    sentiment_polarity_by_sentence[counter] = sentence.sentiment[0]
    counter +=1
    
print(sentiment_polarity_by_sentence)
# Out:
# {0: 0.0, 1: -0.09375, 2: 0.0, 3: 0.1290909090909091, 4: 0.175, 5: 0.24218855218855218, 6: 0.21333333333333335, 7: 0.1, 8: 0.24789772727272727, 9: 0.1785353535353535, 10: -0.5, 11: -0.4, 12: 0.14566326530612245, 13: 0.15833333333333333, 14: 0.2505952380952381, 15: 0.057638888888888885, 16: 0.10416666666666669, 17: 0.05, 18: 0.09079545454545454, 19: -0.09555555555555556, 20: 0.3, 21: 0.27499999999999997, 22: 0.0, 23: 0.024999999999999994, 24: 0.24374999999999997, 25: 0.1, 26: -0.19166666666666665, 27: -0.05, 28: 0.0, 29: -0.21250000000000002, 30: 0.0, 31: 0.0, 32: -0.05, 33: 0.0, 34: 0.0, 35: 0.0, 36: -0.5, 37: -0.2, 38: -0.5, 39: 0.8, 40: 0.0, 41: -0.1875, 42: 0.0, 43: 0.05, 44: 0.0, 45: 0.0, 46: 0.0, 47: 0.1, 48: 0.0, 49: 0.0, 50: 0.02888888888888888, 51: 0.5625, 52: -0.09722222222222222, 53: -0.025, 54: 0.0, 55: 0.0, 56: -0.025000000000000005, 57: 0.0, 58: 0.0, 59: 0.0, 60: 0.0, 61: -0.049999999999999996, 62: 0.18333333333333335, 63: 0.48000000000000004, 64: 0.4916666666666667, 65: 0.55, 66: 0.36453423120089784, 67: -0.21027777777777779, 68: 0.21428571428571427, 69: 0.1, 70: 0.0, 71: 0.49583333333333335, 72: 0.16666666666666669, 73: -0.2866666666666667, 74: 0.7, 75: 0.2, 76: 0.07916666666666666, 77: 0.0, 78: 0.0, 79: 0.8, 80: 0.1, 81: 0.125, 82: 0.625, 83: 0.07291666666666666, 84: 0.0, 85: 0.0, 86: 0.0, 87: 0.0, 88: 0.25, 89: 0.0, 90: 0.43333333333333335, 91: 0.8, 92: -0.125, 93: 0.0, 94: 0.0, 95: 0.0, 96: -0.25, 97: 0.6, 98: 0.6, 99: 0.6, 100: 0.5, 101: -0.05, 102: -0.1875, 103: 0.0, 104: 0.0, 105: -0.007142857142857145, 106: 0.0, 107: -0.39375, 108: 0.0, 109: 0.0, 110: 0.0, 111: 0.0, 112: -0.17152777777777778, 113: 0.0, 114: 0.0, 115: 0.0, 116: 0.0, 117: 0.0, 118: 0.25, 119: 0.0, 120: 0.2, 121: 0.0, 122: 0.0, 123: 0.0, 124: -0.15555555555555559, 125: 0.1, 126: 0.0, 127: 0.0, 128: 0.0, 129: 0.0, 130: 0.0, 131: -0.16666666666666666, 132: 0.0, 133: 0.1, 134: 0.0, 135: 0.0, 136: 0.0, 137: 0.5, 138: 0.0, 139: 0.8, 140: 0.0, 141: 0.0, 142: 0.0, 143: 0.0, 144: 0.0, 145: 0.0, 146: 0.0, 147: 0.2, 148: 0.125, 149: 0.0, 150: 0.25, 151: 0.0, 152: 0.0, 153: 0.05, 154: 0.0, 155: 0.0, 156: 0.1, 157: 0.2, 158: 0.0, 159: 0.0, 160: 0.0, 161: 0.0, 162: 0.2, 163: 1.0, 164: 0.0, 165: -0.4, 166: 0.0, 167: 0.0, 168: -0.3076923076923077, 169: 0.3, 170: 0.1923076923076923, 171: 0.31, 172: 0.37777777777777777, 173: 0.09305555555555556, 174: -0.3666666666666667, 175: 0.060416666666666674, 176: -0.084375, 177: 0.0, 178: 0.05, 179: 0.19516233766233765, 180: 0.030129870129870128, 181: 0.13133333333333333, 182: 0.0, 183: 0.2, 184: 0.0, 185: 0.16, 186: 0.04999999999999999, 187: 0.0, 188: 0.0, 189: 0.16, 190: 0.0, 191: 0.0, 192: -0.4, 193: 0.0, 194: 0.0, 195: 0.25, 196: 0.0, 197: -0.1, 198: -0.2, 199: 0.0, 200: 0.4666666666666667, 201: -0.2, 202: 0.0, 203: 0.0, 204: 0.14285714285714285, 205: 0.22499999999999998, 206: 0.0, 207: 0.0, 208: 0.22999999999999998, 209: 0.0, 210: -0.03547619047619048, 211: 0.0, 212: 0.0, 213: -0.5, 214: 0.2625, 215: 0.0, 216: 0.049999999999999996, 217: -0.05, 218: 0.0, 219: 0.2, 220: -0.033333333333333354, 221: -0.2722222222222222, 222: 0.35, 223: 0.25, 224: 0.0, 225: 0.3, 226: -0.13173076923076923, 227: -0.4, 228: 0.21428571428571427, 229: 0.4, 230: 0.0, 231: 0.24154761904761904, 232: 1.0, 233: -0.19687500000000002, 234: 0.1, 235: 0.5, 236: 0.0, 237: -0.15, 238: -0.0625, 239: -0.6, 240: 0.5666666666666667, 241: 0.11349999999999999, 242: -0.25, 243: 0.0, 244: 0.0, 245: -0.5, 246: 0.5, 247: 0.0, 248: 0.48000000000000004, 249: 0.0, 250: 0.625, 251: 0.05000000000000002, 252: 0.0, 253: 0.625, 254: 0.0, 255: 0.3, 256: 0.5, 257: 0.0, 258: 0.0, 259: 0.0, 260: 0.0, 261: 0.0, 262: 0.0, 263: -0.125, 264: 0.25, 265: -0.17142857142857146, 266: 0.16, 267: 0.11499999999999999, 268: 0.0, 269: 0.5, 270: -0.19464285714285715, 271: 0.0, 272: 0.0, 273: -0.0625, 274: 0.237012987012987, 275: 0.12374603174603174, 276: 0.2833333333333333, 277: 0.0, 278: 0.0, 279: -0.052083333333333336, 280: 0.17916666666666667, 281: 0.215, 282: 0.0, 283: 0.0, 284: -0.10 ...

# %% [markdown]
# Now, let's try exporting our dictionary to a format that we can use with other programs. A `csv` file is a good option here, as it can handle tabular data of this sort well and can be used with many different types of applications.

# %%
# exporting to CSV
import csv

with open('sentiment_polarity_by_sentence.csv', 'w',  newline='') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in sentiment_polarity_by_sentence.items():
       writer.writerow([key, value])

# %% [markdown]
# Don't worry too much about the syntax here. Basically what we are doing is importing a new Python library (`csv`), and using it to write our dictionary, `sentiment_polarity_by_sentence`, to a new CSV file that will be saved in the same directory as our Jupyter Notebook files.
#
# It's worth noting that with minimal alterations, you could re-use the same block of code to export word or noun phrase counts as csv files.

# %% [markdown]
# > ### Graphing with Google Sheets
#
# Now, we can open this file up in our preferred application. In this example, we'll use Google Sheets.
#
# To do this, first login to your Bates Gmail account, and use the small grid menu on the upper right to open your Google Drive.
#
# Next, simply drag and drop your new CSV file into your Drive account. Once it's finished uploading, right click the file and select Open With --> Google Sheets

# %% [markdown]
# Once you've created your new Google Sheet, highlight the two columns with our data, and select Insert--> Chart.
#
# This will give us a nice line chart that we can customize and even publish online

# %% [markdown]
# -------------
#
# ## Polarity scores by novel
#
# Let's try another example. What if we wanted to plot the polarity score for each of Dicken's novels?

# %%
# First, let's create a list that contains our novels
novels = ['ATaleOfTwoCities','BarnabyRudge','BleakHouse','DavidCopperfield','DombeyandSon','GreatExpectations','HardTimes','LittleDorrit','MartinChuzzlewit','NicholasNickleby','OliverTwist', 'OurMutualFriend', 'TheMysteryofEdwinDrood','TheOldCuriosityShop','ThePickwickPapers']

# Now, let's create an empty dictionary to store our data:
sentiment_polarity_by_novel = {}

# Finally, let's iterate through our list of novels, create a TextBlob of each using our read_file function
# and add the polarity of each to our dictionary as values
for novel in novels:
    newBlob = read_file("data/"+novel+".txt")
    #newBlob = TextBlob(novel)
    s_score = newBlob.sentiment[1]
    sentiment_polarity_by_novel[novel] = s_score

# Just to confirm we are getting what we want:
print(sentiment_polarity_by_novel)
# Out:
# {'ATaleOfTwoCities': 0.4886236201983966, 'BarnabyRudge': 0.5012356923617686, 'BleakHouse': 0.49817774418331007, 'DavidCopperfield': 0.5016802929714901, 'DombeyandSon': 0.504965113094682, 'GreatExpectations': 0.4893475720445764, 'HardTimes': 0.4960002030213268, 'LittleDorrit': 0.498971670531521, 'MartinChuzzlewit': 0.5060088964249315, 'NicholasNickleby': 0.5045282506729171, 'OliverTwist': 0.49169707194251144, 'OurMutualFriend': 0.5010752215032365, 'TheMysteryofEdwinDrood': 0.4966102664407347, 'TheOldCuriosityShop': 0.49767043059895927, 'ThePickwickPapers': 0.48783042927989123}

# %% [markdown]
# Now we can use the same process as above to export this as a CSV file, and then to use that CSV file in Google Sheets to generate a data visualization:

# %%
# exporting to CSV
with open('sentiment_polarity_by_novel.csv', 'w',  newline='') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in sentiment_polarity_by_novel.items():
       writer.writerow([key, value])

# %% [markdown]
# ---
#
# ### Final Quiz
#
# User choice - use the tools and techniques we've reviewed during these lessons to generate a data visualization of your choice using at least one novel from our Dickens corpus.
